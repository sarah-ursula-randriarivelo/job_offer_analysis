# %%
# %run vectorizing.ipynb import X
# %run cleaning.ipynb import df_clean_text as df
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

def find_optimal_clusters(X, max_k = 44):
# the maximum number of cluster should not exceed the half of the documents length
    max_possible_k = min(max_k, len(df) // 2)
    if max_possible_k < 2:
         return 2
# Test for each number of cluster which gives the best score
    k_range = range(2, max_possible_k)
# Stock each cluster and its corresponding score inside the "scores" table 
    scores = []
    for k in k_range:
        try:
            kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
            kmeans.fit(X)
            score = silhouette_score(X, kmeans.labels_)
            scores.append(score)
        except:
            scores.append(-1)  #  Clustering errors

    if not scores or all(s == -1 for s in scores):
        return 2

    best_k = k_range [scores.index(max(scores))]
    print(f"best_k = {best_k}, score = {score}")
    return best_k
    
n_clusters = find_optimal_clusters(X) 
kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X)

df_optimal = df['cluster'].value_counts().reset_index()
df_optimal.columns = ['cluster', 'count']
# Out:
# 5935 lines retrieved from the database
# ['conseiller client (1.0)', 'charge commercial (1.0)', 'charge commercial (1.0)', 'conseiller client (1.0)', 'projet digital (1.0)', 'charge commercial (1.0)', 'projet digital (1.0)', 'charge commercial (1.0)', 'projet digital (1.0)', 'charge commercial (1.0)', 'charge commercial (1.0)', 'tele prospecteur (1.0)', 'charge commercial (1.0)', 'charge commercial (1.0)', 'projet digital (1.0)', 'projet digital (0.4865787701334879)', 'digital projet (0.6177544416899737)', 'projet digital projet (0.6177544416899737)', 'charge commercial (1.0)', 'tele propsecteurphonique (0.3309737955707876)', 'propsecteurphonique specialise (0.33362710221246006)', 'specialise tourisme (0.33362710221246006)', 'tourisme bilingue (0.33362710221246006)', 'tele propsecteurphonique specialise (0.33362710221246006)', 'propsecteurphonique specialise tourisme (0.33362710221246006)', 'specialise tourisme bilingue (0.33362710221246006)', 'tele propsecteurphonique specialise tourisme (0.33362710221246006)', 'propsecteurphonique specialise tourisme bilingue (0.33362710221246006)', 'charge commercial (1.0)', 'charge commercial (1.0)', 'projet digital (1.0)', 'conseiller client (1.0)', 'care specialist (0.7071067811865476)', 'customer care specialist (0.7071067811865476)', 'charge commercial (1.0)', 'auditeur interne (1.0)', 'charge commercial (1.0)', 'projet digital (1.0)', 'charge commercial (1.0)', 'conseiller client (1.0)', 'tele prospecteur (1.0)', 'projet digital (0.4865787701334879)', 'digital projet (0.6177544416899737)', 'projet digital projet (0.6177544416899737)', 'projet digital (0.4865787701334879)', 'digital projet (0.6177544416899737)', 'projet digital projet (0.6177544416899737)', 'charge commercial (1.0)', 'charge commercial (1.0)', 'administratif financier (1.0)', 'coordinateur commercial (1.0)', 'charge commercial (1.0)', 'charge commercial (1.0)', 'charge commercial (1.0)', 'charge commercial (1.0)', 'conseiller client (1.0)', 'tele prospecteur (1.0)', 'tele prospecteur (1.0)', 'projet digital (1.0)', 'charge commercial (1.0)', 'controleur gestion (1.0)', 'charge commercial (1.0)', 'charge commercial (1.0)', 'charge commercial (1.0)', 'projet digital (0.28609659410851973)', 'digital projet (0.36322472867943983)', 'projet digital projet (0.36322472867943983)', 'projet comptable (0.46700618546617395)', 'digital projet comptable (0.46700618546617395)', 'projet digital projet comptable (0.46700618546617395)', 'front end (1.0)', 'conseiller client (0.652971450927119)', 'client bilingue (0.7573825217643546)', 'administratif financier (1.0)', 'charge commercial (1.0)', 'charge commercial (1.0)', 'charge commercial (1.0)', 'conseiller client (1.0)', 'technico commercial (1.0)', 'charge commercial (1.0)', 'tele prospecteur (1.0)', 'coordinateur commercial (1.0)', 'projet digital (1.0)', 'tele prospecteur (1.0)', 'controleur gestion (1.0)', 'charge commercial (1.0)', 'collaborateur comptable (1.0)', 'projet digital (0.28609659410851973)', 'digital projet (0.36322472867943983)', 'projet digital projet (0.36322472867943983)', 'projet comptable (0.46700618546617395)', 'digital projet comptable (0.46700618546617395)', 'projet digital projet comptable (0.46700618546617395)', 'charge commercial (1.0)', 'dessinateur projeteur (1.0)', 'ressources humaines (1.0)', 'collaborateur comptable (1.0)', 'tele propsecteurphonique (0.3309737955707876)', 'propsecteurphonique specialise (0.33362710221246006)', 'specialise tourisme (0.33362710221246006)', 'tourisme bilingue (0.33362710221246006)', 'tele propsecteurphonique specialise (0.33362710221246006)', 'propsecteurphonique specialise tourisme (0.33362710221246006)', 'specialise tourisme bilingue (0.33362710221246006)', 'tele propsecteurphonique specialise tourisme (0.33362710221246006)', 'propsecteurphonique specialise tourisme bilingue (0.33362710221246006)', 'projet digital (0.4865787701334879)', 'digital projet (0.6177544416899737)', 'projet digital projet (0.6177544416899737)', 'charge commercial (1.0)', 'charge comm ...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Found 2447 unique titles out of 5935 total entries.
# Generating embeddings...
# Batches:   0%|          | 0/77 [00:00<?, ?it/s]
# Performing clustering...
#
# --- Semantic Job Title Clusters ---
#
# **Cluster 0 (Label 123):**
#   *   Titles: conseiller client, conseillers clients anglophones, conseiller client francophone experimente, conseiller client francophone, conseiller client bilingue fr
#   *   ... and 26 more.
#
# **Cluster 1 (Label 55):**
#   *   Titles: administration comptabilite, procurment officer, administrateur systemes reseau, project managers, maintenance project officer
#   *   ... and 53 more.
#
# **Cluster 2 (Label 162):**
#   *   Titles: coursier moto, moyen genereaux, motos neufs, moyens generaux, coursier livreur moto
#   *   ... and 1 more.
#
# **Cluster 3 (Label 49):**
#   *   Titles: premiere seconde ligne, acheteur hf, acheteur, acheteur bb, administratif ligne
#   *   ... and 5 more.
#
# **Cluster 4 (Label 114):**
#   *   Titles: reseau, recouvrement, recrutement integration, recrutement, recruteur
#   *   ... and 6 more.
#
# **Cluster 5 (Label 97):**
#   *   Titles: exploitation, charge commercial, commercial, coordinateur commercial, exploitant commercial
#   *   ... and 7 more.
#
# **Cluster 6 (Label 52):**
#   *   Titles: egerie ambassadrice marque, professeur danglais primaire, instituteur etudiant inscrit cned, commerciaux, professeur dallemand
#   *   ... and 51 more.
#
# **Cluster 7 (Label 145):**
#   *   Titles: test tiana, test
#
# **Cluster 8 (Label 205):**
#   *   Titles: travel, voyage, dagence voyage, expedition, travel consultant
#
# **Cluster 9 (Label 24):**
#   *   Titles: qaqc, qhse, coach qualite departement appel, qualite, coach qualite
#   *   ... and 13 more.
#
# **Cluster 10 (Label 67):**
#   *   Titles: sourcing qualification cv, talent acquisition specialist career development specialist, talent acquisition specialist, talent acquisition, talent acquisition specialist recruteur ae
#   *   ... and 1 more.
#
# **Cluster 11 (Label 124):**
#   *   Titles: juriste, achat commissionnaire antsohihy, consultant juridique fiscal, juridique, directeur fiscalite
#   *   ... and 18 more.
#
# **Cluster 12 (Label 71):**
#   *   Titles: stocks, gestionnaire stocks, gestionnaire stock, collaborateurtrice section stock, gestionnaire stock approvisionnement femme rhieuf
#   *   ... and 5 more.
#
# **Cluster 13 (Label 91):**
#   *   Titles: dessinateur metreur poste base, dessinateur, dessinateurrices dao, dessinateur dao dd, declarant douane
#   *   ... and 13 more.
#
# **Cluster 14 (Label 262):**
#   *   Titles: auditeurs jiorsseniors recaudit, auditeur agriculture biologique, auditeur interne confirme, inspecteur nr, directeur audit controle
#   *   ... and 16 more.
#
# **Cluster 15 (Label 192):**
#   *   Titles: commissions, invoicing, production paysannat, payroll, partenariat paysannat
#   *   ... and 1 more.
#
# **Cluster 16 (Label 64):**
#   *   Titles: conducteurs machine, conducteur machine automatisee, directeur securite, conducteur travaux, projeteur coffrage ferraillage
#   *   ... and 87 more.
#
# **Cluster 17 (Label 45):**
#   *   Titles: commity confirme, commity ava dia, commity, commity instagram tiktok, commity cm
#   *   ... and 3 more.
#
# **Cluster 18 (Label 284):**
#   *   Titles: bras droit ceo fren, bras droit ceo
#
# **Cluster 19 (Label 206):**
#   *   Titles: ingenieurs developpement java confirme modernisation dapplication perspectives devolution ref devjava, developpement rh, ingenieurs developpement java confirme modernisation dapplication perspectives devolution, developpement business, business developper
#   *   ... and 5 more.
#
# **Cluster 20 (Label 61):**
#   *   Titles: conseiller client tele propsecteuroperateur bilingue, repartition routiere tele propsecteurtravail, tele prospecteur, tele propsecteurphonique specialise tourisme bilingue, agents tele propsecteurvente
#   *   ... and 35 more.
#
# **Cluster 21 (Label 161):**
#   *   Titles: electromenager, electricite electronique, automaticien, electronicien, electricien
#   *   ... and 19 more.
#
# **Cluster 22 (Label 160):**
#   *   Titles: work force management rh, rh, rh opccfin tnr, interim rrh, administration rh
#   *   ... and 2 more.
#
# **Cluster 23 (Label 42):**
#   *   Titles: delegue commercial, delegue medical dm toliara, delivrability, delegue medical dm, delegue general
#   *   ... and 2 more.
#
# **Cluster 24 (Label 226):**
#   *   Titles: planificateur jior, planificateur, jior due diligence and analysis specialist english, comptable jior, comptables jiors
#   *   ... and 7 more.
#
# **Cluster 25 (Label 9):**
#   *   Titles: solaire, ingenieur solaire, ingenieur commercial, ingenieur technique int tnn, ingenieur fluide
#   *   ... and 40 more.
#
# **Cluster 26 (Label 156):**
#   *   Titles: call, call sup call, call center, call officer, call center team leader
#   *   ... and 2 more.
#
# **Cluster 27 (Label 15):**
#   *   Titles: content, salesforce, documentaliste, webmaster, wordpress
#   *   ... and 4 more.
#
# **Cluster 28 (Label 19):**
#   *   Titles: projet digital projets moa, projet digital site, projet digital chantier metal, projet digital depot, projet digital projet seo sea
#   *   ... and 132 more.
#
# **Cluster 29 (Label 10):**
#   *   Titles: cuisinier, cuisinierpatissier, patissier, filaire, patissiercuisinier
#   *   ... and 16 more.
#
# **Cluster 30 (Label 26):**
#   *   Titles: guichetier payeur polyvalent, comptable polyvalent confirme, daccueil polyvalente, polyvalent magasin, polyvalent
#   *   ... and 13 more.
#
# **Cluster 31 (Label 116):**
#   *   Titles: comptable tresorerie, comptable, comptable principal, comptable comptabilite belge, collaborateur saisie collaborateur compable
#   *   ... and 50 more.
#
# **Cluster 32 (Label 57):**
#   *   Titles: expert comptable, expert data, expert referencement seo sea experimente, sales expert it, expert comptabilite
#   *   ... and 10 more.
#
# **Cluster 33 (Label 193):**
#   *   Titles: compliance qhse rse, site rst, rse, rssi, production rsp tnn
#   *   ... and 1 more.
#
# **Cluster 34 (Label 121):**
#   *   Titles: aide maintenancier, aide comptable, aide labo, gardienne denfants aide familiale quebec canada quebec, aide administratif
#   *   ... and 1 more.
#
# **Cluster 35 (Label 281):**
#   *   Titles: gestionnaire flotte location, operatuer suivie flotte, flotte, operateur suivi flotte
#
# **Cluster 36 (Label 250):**
#   *   Titles: professeur malagasy, interprete chinois malagasy malagasy chinois, adjoint atelier production montage madagascar anosivavaka, adjoint administratif financier island brush company ile maurice madagascar anosivavaka, cotry madagascar
#
# **Cluster 37 (Label 98):**
#   *   Titles: gestionnaire transport, transport logistique, directeur logistique transport, regulateurs planificateur transport, logisticien transport travaux pylones
#   *   ... and 1 more.
#
# **Cluster 38 (Label 213):**
#   *   Titles: bureau detude, dessinateur bureau detude, bureau detudes respbe, bureau detudes ftth, topographe bureau detude
#
# **Cluster 39 (Label 28):**
#   *   Titles: marketing, growth hacker, growth marketing, affiliate, webmarketer
#   *   ... and 10 more.
#
# **Cluster 40 (Label 170):**
#   *   Titles: fullstack confirme, fullstack, developpeurs fullstack, fullstack confirme dev, developpeurs fullstack confirmes
#   *   ... and 4 more.
#
# **Cluster 41 (Label 74):**
#   *   Titles: economiste construction general, enseignant economie droit, econome, gouvernance locale activites economiques, professeur sciences economiques sociales
#   *   ... and 2 more.
#
# **Cluster 42 (Label 109):**
#   *   Titles: ched manakara, mpanadio
#
# **Cluster 43 (Label 271):**
#   *   Titles: app mobile, mobile, testeur service performance reseau mobile, mobile developers, ux mobile
#   *   ... and 4 more.
#
# **Cluster 44 (Label 37):**
#   *   Titles: adjoint magasin, adjoint responsbale production arp tnn, adjoint qualite, adjoint maintenance, daf adjoint
#   *   ... and 7 more.
#
# **Cluster 45 (Label 11):**
#   *   Titles: customer care specialist commerce bilingue, customer success, merchandiser, sales, sales representative
#   *   ... and 25 more.
#
# **Cluster 46 (Label 85):**
#   *   Titles: consultant commication institutionnelle, consultant bi, human resources business partner, consultant rh, consultant data bi
#   *   ... and 17 more.
#
# **Cluster 47 (Label 183):**
#   *   Titles: ingenieur python, developpeureuse python ia llm rag freelance, python, python saas, pythonfast api
#   *   ... and 5 more.
#
# **Cluster 48 (Label 38):**
#   *   Titles: lead java, javaphp, java, java javasenior, java swing
#   *   ... and 6 more.
#
# **Cluster 49 (Label 134):**
#   *   Titles: depot, site majga, boutique majga, boutique
#
# **Cluster 50 (Label 143):**
#   *   Titles: achat, achats, achats internationaux, achat stock
#
# **Cluster 51 (Label 51):**
#   *   Titles: chauffeur base, chauffeur, chauffeur direction habitant imperativement andoharanofotsy, chauffeur elevateur, chauffeur direction
#   *   ... and 34 more.
#
# **Cluster 52 (Label 23):**
#   *   Titles: developpeurs aspose, presentateurspresentatrices
#
# **Cluster 53 (Label 79):**
#   *   Titles: gestionnaire location commity ia, activites province, urbaniste amenagement
#
# **Cluster 54 (Label 31):**
#   *   Titles: data analyst anglophone, it analyst, analyste stock, business analyst, management reporting analyst
#   *   ... and 41 more.
#
# **Cluster 55 (Label 153):**
#   *   Titles: applicatif, apprenti dao ref apprenti daoiste, appui operationnel, apprenti data scientist, apprenti frc
#   *   ... and 4 more.
#
# **Cluster 56 (Label 218):**
#   *   Titles: front, back, back end, front end, front end expert
#   *   ... and 3 more.
#
# **Cluster 57 (Label 175):**
#   *   Titles: gestionnaire paiements fournisseurs internationaux hf, gestionnaire immobilisations, gestionnaire comptes, gestionnaire maintenance confirme, gestionnaire rh fr
#   *   ... and 41 more.
#
# **Cluster 58 (Label 188):**
#   *   Titles: administratif financier coach mentor, coach formateur, coach sportif multidisciplinaire, recherche coach sportif online, coach carriere
#   *   ... and 4 more.
#
# **Cluster 59 (Label 8):**
#   *   Titles: developpement dagence, dapplications smartphone, dao, ingenieur daffaire, daudit
#   *   ... and 8 more.
#
# **Cluster 60 (Label 196):**
#   *   Titles: controleur qualite ctq tnn, comptable controleur gestion, controle qualite, controleur gestion, controle gestion
#   *   ... and 25 more.
#
# **Cluster 61 (Label 60):**
#   *   Titles: coursier livreur, coursier, cosmetiques, cosmetologue, coursier coursiersodiat
#   *   ... and 10 more.
#
# **Cluster 62 (Label 70):**
#   *   Titles: aide magasinier, magasin pieces rechange, magasinier, magasin, magasinier aide
#   *   ... and 9 more.
#
# **Cluster 63 (Label 135):**
#   *   Titles: freelance interfaces integrations crm, developpeureuse net freelance, business bb freelance remote approche humaine commerciale innovante, business freelance ar mois, freelance it
#   *   ... and 5 more.
#
# **Cluster 64 (Label 243):**
#   *   Titles: direction, assistance direction, asssitante direction
#
# **Cluster 65 (Label 12):**
#   *   Titles: inventoriste, infographiste, projet digital projet informatique expertise net angular, reseaux it, informaticien
#   *   ... and 49 more.
#
# **Cluster 66 (Label 120):**
#   *   Titles: finance financemanager, administratif financier, directeur financier ressources humaines, financier, directeur financier
#   *   ... and 23 more.
#
# **Cluster 67 (Label 29):**
#   *   Titles: laborantin, laboratoire, atelier particulier, particuliere, laboratin
#   *   ... and 4 more.
#
# **Cluster 68 (Label 141):**
#   *   Titles: carburant location, cariste magasin, dieseliste, carburant, cariste
#
# **Cluster 69 (Label 216):**
#   *   Titles: boulanger patissier, boulanger, preparatricevendeuse boulangerie, rayon poissonerie boucherie, boulangers
#   *   ... and 1 more.
#
# **Cluster 70 (Label 125):**
#   *   Titles: securite routiere sinorsr, securite parking, securite sante travail, securite ags tmm, securite
#   *   ... and 4 more.
#
# **Cluster 71 (Label 172):**
#   *   Titles: conformite systeme, conformite groupe, concepteur formations conformite reglementaire, conformite
#
# **Cluster 72 (Label 202):**
#   *   Titles: designer experimente, comptable experimente, wordpress experimente, directeur publication experimente, commerciaux experimentes
#   *   ... and 2 more.
#
# **Cluster 73 (Label 59):**
#   *   Titles: cc engineer, ingenieur industriel, industrie, electricien industriel, network engineer
#   *   ... and 11 more.
#
# **Cluster 74 (Label 83):**
#   *   Titles: prise rendez, prise rdv op co, prise rendez vousrefac, prise rendez physique, operateur prise rdv bb
#   *   ... and 3 more.
#
# **Cluster 75 (Label 130):**
#   *   Titles: agents billetteries agents receptifs, agents dappui projet, agents credit pme, agents transit, agents commerciaux
#   *   ... and 5 more.
#
# **Cluster 76 (Label 25):**
#   *   Titles: standardistes bilingues, standardiste, compositeur, maintenancier
#
# **Cluster 77 (Label 58):**
#   *   Titles: graphic designer, graphic designer anglophone, motion designer, designer uiux, designer
#   *   ... and 5 more.
#
# **Cluster 78 (Label 20):**
#   *   Titles: paoisteconducteur machines, paoiste, admin paie, paie, administration rh paie rap
#   *   ... and 1 more.
#
# **Cluster 79 (Label 276):**
#   *   Titles: javaangularpython, javaangular devfullstack
#
# **Cluster 80 (Label 1):**
#   *   Titles: developpeureuse jior front end moderne laravel, syliussymfony, laravel integration api data flows, full stack js symfony, php symfony
#   *   ... and 10 more.
#
# **Cluster 81 (Label 69):**
#   *   Titles: business, business it, business resilience, business it digital, business bb
#   *   ... and 10 more.
#
# **Cluster 82 (Label 33):**
#   *   Titles: consultant si ref datacsi, fctional analyst ref fa, investment ref imedbm, team leader ref gmb sea, comptable ref datacompta
#   *   ... and 1 more.
#
# **Cluster 83 (Label 87):**
#   *   Titles: conseiller client germanophone, conseillers client franco hispanophone, traffic franco germanophone, it hotline francophone, operateur germanophone
#   *   ... and 2 more.
#
# **Cluster 84 (Label 138):**
#   *   Titles: operateur surveillance, ingenieur surveillance projets, ingenieur surveillance projet, tracking, tracking video surveillance
#
# **Cluster 85 (Label 259):**
#   *   Titles: tulear, maintenance jardinier tulear, serveuse tulear, maintenance tulear
#
# **Cluster 86 (Label 126):**
#   *   Titles: recouvrement alaotra, pizzaiolo, caissier, caissiere snack pizza, caissiere
#   *   ... and 10 more.
#
# **Cluster 87 (Label 187):**
#   *   Titles: technico commercial, technico, techniciens frigoriste, ingenieurs techniciens agricoles, technologie linformation gestion connaissances
#   *   ... and 5 more.
#
# **Cluster 88 (Label 122):**
#   *   Titles: python bilingue, coach production bilingue, bilan, voyage bilingue experimente, coach qualite bilingue fr uk
#   *   ... and 9 more.
#
# **Cluster 89 (Label 214):**
#   *   Titles: reservation novotel, ticketing, reservations, booking cotation, agents booking
#   *   ... and 1 more.
#
# **Cluster 90 (Label 96):**
#   *   Titles: powerapps, power bi, analyste talend business objects power bi, analyste power bi, analyste power bi etl sql
#
# **Cluster 91 (Label 264):**
#   *   Titles: golang, statiticien, gouvernante generale, gouvernante, gouvernante gardien
#
# **Cluster 92 (Label 44):**
#   *   Titles: ingenieur devops, ingenieur devops cdi full remote, aws developerengineer, devops apprenti mlops, win dev
#   *   ... and 3 more.
#
# **Cluster 93 (Label 4):**
#   *   Titles: ressources humaines, developpement ressources humaines, ressources humaines base, gestionnaire ressources humaines, ressources humaines acquisition talents
#   *   ... and 3 more.
#
# **Cluster 94 (Label 112):**
#   *   Titles: centre, formation, regional centre, centre formation, team leader centre dappel
#
# **Cluster 95 (Label 146):**
#   *   Titles: accot, key accot officer, accots receivable specialist, accot executive, key accot
#   *   ... and 4 more.
#
# **Cluster 96 (Label 200):**
#   *   Titles: frigoriste sav, frigoriste, specialise froid, frigoriste maintenance
#
# **Cluster 97 (Label 86):**
#   *   Titles: receptionniste anglophone f, receptionniste, receptionniste anjajavy, receptionniste dhotel, controleur receptionniste toliara
#   *   ... and 5 more.
#
# **Cluster 98 (Label 139):**
#   *   Titles: confirme, surete groupe, php confirme, confirme cnet
#
# **Cluster 99 (Label 82):**
#   *   Titles: concepteur, concepteur modules elearning specialise gpt, modeleur bim, modelisation developpement, modeleur talentueux
#   *   ... and 5 more.
#
# **Cluster 100 (Label 78):**
#   *   Titles: maintenance, qual maintenance q, ingenieur installations solaires maintenance, maintenance entretien panneaux solaires, maintenance industrielle
#   *   ... and 16 more.
#
# **Cluster 101 (Label 65):**
#   *   Titles: commerciaux terrains, projet digital plateau centre dappel, projet digital plateau, commerciaux terrain, coordonateur terrain certification
#   *   ... and 1 more.
#
# **Cluster 102 (Label 154):**
#   *   Titles: node js confirme, frontend javascript, nodejs, javascript
#
# **Cluster 103 (Label 169):**
#   *   Titles: dexploitation maintenance, collaborateur dexpansion, dexpertise, dexploitation, chaine production produits dexport
#
# **Cluster 104 (Label 244):**
#   *   Titles: comptable hf tsaralalana
#
# **Cluster 105 (Label 168):**
#   *   Titles: referent technique, referent projets, referent projet
#
# **Cluster 106 (Label 171):**
#   *   Titles: redaction seo copywriting, redacteur bac, redacteurtrice cours medecine sante, redacteur polyvalent, redacteur seo confirme
#   *   ... and 10 more.
#
# **Cluster 107 (Label 103):**
#   *   Titles: developpeurs seniors front end angular, angular, fullstack angular java dev full, developper php angular, programmeur net angular
#   *   ... and 5 more.
#
# **Cluster 108 (Label 93):**
#   *   Titles: administrateur ventes region, operateur vente ligne cc, ingenieurs commerciaux vente dassurance mutuelle sante, recherche expert creation tnel vente, adv administration ventes btob
#   *   ... and 25 more.
#
# **Cluster 109 (Label 128):**
#   *   Titles: produit, qualite produit poste base ivato, lancement produit, projets ruraux agronomie
#
# **Cluster 110 (Label 3):**
#   *   Titles: , erp, it, om
#
# **Cluster 111 (Label 204):**
#   *   Titles: sage, consultante technique sage, consultante fonctionnelle sage, consultant confirme erp sage x
#
# **Cluster 112 (Label 104):**
#   *   Titles: php, phplaravel full stack, phplaravel, php java
#
# **Cluster 113 (Label 286):**
#   *   Titles: plombier
#
# **Cluster 114 (Label 246):**
#   *   Titles: technique btp, projet digital projet btp, btp, ingenieur structure btp, superieur btp
#   *   ... and 7 more.
#
# **Cluster 115 (Label 47):**
#   *   Titles: mecanicien poids lourds, mecanicien, ambilombe, mecanique, mecanicien poids lourds engins fort dauphinanosy
#   *   ... and 8 more.
#
# **Cluster 116 (Label 164):**
#   *   Titles: graduate quality project, project, project ref pm
#
# **Cluster 117 (Label 66):**
#   *   Titles: operations, operations commerce, operation, operationnel dactivite, general operations jour nuit
#   *   ... and 6 more.
#
# **Cluster 118 (Label 32):**
#   *   Titles: credit, analyste risque credit, fraude risques, analyste credit moramanga, risques liquidite credit
#   *   ... and 2 more.
#
# **Cluster 119 (Label 247):**
#   *   Titles: coach shopify, shopify growth, phpliquid woocommerce shopify, shopify
#
# **Cluster 120 (Label 7):**
#   *   Titles: designer textile industriel, fibre optique, production textile, projet digital production textile, projet digital rayon
#   *   ... and 8 more.
#
# **Cluster 121 (Label 133):**
#   *   Titles: community management, community prospection digitale
#
# **Cluster 122 (Label 80):**
#   *   Titles: service, service generaux, element libre service, employe libre serviceels kiabi, service informatique
#   *   ... and 3 more.
#
# **Cluster 123 (Label 30):**
#   *   Titles: full stack experimente, full stack php ds, full stack confirme, full stack, frontend nextjs
#   *   ... and 14 more.
#
# **Cluster 124 (Label 76):**
#   *   Titles: qualite environnement suivievaluation, housekeeping, qhygiene securite environnement, controle qualite hygiene, hygiene securite environnement
#   *   ... and 2 more.
#
# **Cluster 125 (Label 185):**
#   *   Titles: transit, achats transit, transit transactions financieres, transit douane prod man
#
# **Cluster 126 (Label 50):**
#   *   Titles: integrateur solutions saas, automatisation integration saas, automatisation ia, ingenieur qa automation, python odoo automatisation ia
#
# **Cluster 127 (Label 177):**
#   *   Titles: comptable fournisseur, reglement fournisseur, sourcing relations fournisseurs
#
# **Cluster 128 (Label 34):**
#   *   Titles: formateur technologies avancees transformation digitale, formateur nacre academy, formateurs excel, formateur sst, matre dhotel formateur restauration tulear
#   *   ... and 19 more.
#
# **Cluster 129 (Label 48):**
#   *   Titles: acheteur logisticien, consultant logistique, logistique, gestionnaire administratif logistique vatovavy, planificateur logistique
#   *   ... and 20 more.
#
# **Cluster 130 (Label 261):**
#   *   Titles: team leader operations commerciales, team lead developpeurs, team leader fren, noc team leader, team leader enfr
#   *   ... and 5 more.
#
# **Cluster 131 (Label 184):**
#   *   Titles: sav numerique, specialise sav, sav experimente, sav
#
# **Cluster 132 (Label 39):**
#   *   Titles: enseignant sciences, enseignant allemand, conseil, enseignants, vendeurs conseil
#   *   ... and 9 more.
#
# **Cluster 133 (Label 18):**
#   *   Titles: projet digital datelier garage, projet digital datelier, atelier, projet digital datelier vl, datelier production ufi
#   *   ... and 2 more.
#
# **Cluster 134 (Label 278):**
#   *   Titles: commication, commication officer
#
# **Cluster 135 (Label 181):**
#   *   Titles: general ledger accotant, tax and general ledger accountant
#
# **Cluster 136 (Label 148):**
#   *   Titles: corporate dossiers dassurances, dossier comptable, dossiers comptables
#
# **Cluster 137 (Label 110):**
#   *   Titles: ouvrier polyvalent chantier maintenance, administratif magasinier chantier, surveillant chantier mamoa, chantier
#
# **Cluster 138 (Label 75):**
#   *   Titles: testeur logiciel, expert recettage testing logiciel, logiciel, architecte logiciel
#
# **Cluster 139 (Label 210):**
#   *   Titles: securite systemes dinformation, analyste metiers systeme informatique, systemes dinformation, systeme informatique, systeme management qualite
#   *   ... and 3 more.
#
# **Cluster 140 (Label 252):**
#   *   Titles: assistan commerce, sap developper, prestataire ajouter produits application commerce, assistan comptable asstc, sap abap
#
# **Cluster 141 (Label 16):**
#   *   Titles: operateur comptable, operateur traitement donnees techniques btp, operateurs polyvalents, operateur incinerateur, operateur noc
#   *   ... and 15 more.
#
# **Cluster 142 (Label 186):**
#   *   Titles: developeur bubble, developeur full stack, developeur wordpress
#
# **Cluster 143 (Label 115):**
#   *   Titles: back office geolocalisation interim, geomaticien sig, equipements geolocalisation, back office geolocalisation
#
# **Cluster 144 (Label 166):**
#   *   Titles: gestionnaire campagnes publicitaires, pose entretien visuels publicitaires
#
# **Cluster 145 (Label 178):**
#   *   Titles: dapplication mobile react native, react js react js, react native, react js, react nativeexpo
#   *   ... and 3 more.
#
# **Cluster 146 (Label 234):**
#   *   Titles: gestionnaire dentrepot, dentretien, juriste dentreprise, homme dentretien polyvalent
#
# **Cluster 147 (Label 100):**
#   *   Titles: coordonnateur demarche rse, coordonnateur regional, coordonnateur impact social, coordinatrice, coordonnateur regional antsiranana
#
# **Cluster 148 (Label 140):**
#   *   Titles: technique comptable, technique, methodes, methode, technique maintenance
#   *   ... and 6 more.
#
# **Cluster 149 (Label 14):**
#   *   Titles: collecteurs col port berge, collecte fond, demarcheur bb
#
# **Cluster 150 (Label 107):**
#   *   Titles: preparateurrice, preparateur carrossier, preparateur production plans maquettes bim, educatrice prescolaire, preparateurrice ref bbpmg prp
#   *   ... and 5 more.
#
# **Cluster 151 (Label 254):**
#   *   Titles: revenue assurance, assurance, assurance qualite, v assurance, ingenieur assurance qualite logicielle
#   *   ... and 1 more.
#
# **Cluster 152 (Label 72):**
#   *   Titles: sous traitant, climaticien, dieteticien
#
# **Cluster 153 (Label 167):**
#   *   Titles: back end sqlprogress openedge
#
# **Cluster 154 (Label 211):**
#   *   Titles: couple femme menage homme tout faire, femmes menage polyvalentes, femme menage, gouvernante femme menage, femme menage fm snm
#   *   ... and 2 more.
#
# **Cluster 155 (Label 263):**
#   *   Titles: integrateur odoo, integrateur, integrateur prestashopwordpress, integrateur wordpress, integrateur experimente
#   *   ... and 3 more.
#
# **Cluster 156 (Label 176):**
#   *   Titles: java talend, talend, talend devtalendrh
#
# **Cluster 157 (Label 2):**
#   *   Titles: production atsinanana, production, production broderie machine, operateur production, ite production soufflage pet
#   *   ... and 7 more.
#
# **Cluster 158 (Label 158):**
#   *   Titles: gla, gpao
#
# **Cluster 159 (Label 189):**
#   *   Titles: merchandiser base tan, tan rz
#
# **Cluster 160 (Label 248):**
#   *   Titles: business tsimbazaza, gestionnaire projet tsimbazaza
#
# **Cluster 161 (Label 5):**
#   *   Titles: hote, hse, formation hsse, hse rhse, hsse
#   *   ... and 4 more.
#
# **Cluster 162 (Label 242):**
#   *   Titles: supply chain, demand planner projet digital projet supply chain hf, directeur supply chain
#
# **Cluster 163 (Label 101):**
#   *   Titles: extraction donnees, gestion base donnees, saisie donnees, controleur bases donnees
#
# **Cluster 164 (Label 163):**
#   *   Titles: vendeurs conseil materiaux construction, ouvrier lamineur materiaux composites, materiels energies
#
# **Cluster 165 (Label 197):**
#   *   Titles: graphiste illustrateur, graphiste, graphiste designer, graphiste illustrateurrice, poste graphiste confirme
#   *   ... and 15 more.
#
# **Cluster 166 (Label 118):**
#   *   Titles: controleur maintenance poids lourds, electricen poids lourds, adjoint gestion flux poids lourds, electronicien poids lourds, pneumaticien poids lourd
#
# **Cluster 167 (Label 236):**
#   *   Titles: offre, offre technique
#
# **Cluster 168 (Label 40):**
#   *   Titles: business analyst odoo, consultant fonctionnel odoo, odoo, zoho, business analyst odoo bilingue
#   *   ... and 6 more.
#
# **Cluster 169 (Label 283):**
#   *   Titles: webflow
#
# **Cluster 170 (Label 117):**
#   *   Titles: transcripteurs audio franais canadien, collaborateurstrices experimentees transcription fichiers audio, transcripteur medical, transcripteur audio fr, transcripteur correcteur audio
#
# **Cluster 171 (Label 21):**
#   *   Titles: cadre doperation, doperation, dessinateur autocad, cadre production, cadremanager
#   *   ... and 3 more.
#
# **Cluster 172 (Label 46):**
#   *   Titles: pharmacien diplome, medecin, comptoir pharmacie, pharmacien, biomedical
#   *   ... and 1 more.
#
# **Cluster 173 (Label 182):**
#   *   Titles: copywriter ghostwriter commity
#
# **Cluster 174 (Label 92):**
#   *   Titles: service advisor secteur automobile, parc auto, coupe, coupe rrc, parc automobile
#
# **Cluster 175 (Label 68):**
#   *   Titles: acheteur anglophone, gestionnaire back office anglophone, operateur anglophone, bilingual accotant, production anglophone
#   *   ... and 8 more.
#
# **Cluster 176 (Label 94):**
#   *   Titles: seo, seo affiliation, consultant seo, expert seo backlinks, expert seo
#   *   ... and 2 more.
#
# **Cluster 177 (Label 129):**
#   *   Titles: forestier, responsables site plantation bambou, plantation
#
# **Cluster 178 (Label 208):**
#   *   Titles: digital content editor, visual content creator motion storytelling reseaux
#
# **Cluster 179 (Label 144):**
#   *   Titles: interimresponsable pole conseils, pole maintenance, pole inspector
#
# **Cluster 180 (Label 245):**
#   *   Titles: outdoor, location, site
#
# **Cluster 181 (Label 149):**
#   *   Titles: chat operators, communication evenementiel, communication, social behavior change communication officer
#
# **Cluster 182 (Label 173):**
#   *   Titles: lean management reporting resp accco, reporting financial controller, budget reporting
#
# **Cluster 183 (Label 137):**
#   *   Titles: achats approvisionnements, dapprovisionnement, approvisionneur local, approvisionnements, approvisionnement
#   *   ... and 1 more.
#
# **Cluster 184 (Label 232):**
#   *   Titles: categories
#
# **Cluster 185 (Label 272):**
#   *   Titles: dessinateurs dessinatrices bim plan topographique, topographes, topographe, geometre topographe, recrutement massif dessinateursdessinatrices plan topographique traitement reseaux
#
# **Cluster 186 (Label 229):**
#   *   Titles: estheticienne suarez, estheticienne masseuse, masseuse suarez, masseuses therapeutes, masseuse
#
# **Cluster 187 (Label 113):**
#   *   Titles: chiffreur, chimiste, production chimiste, bio chimiste cosmetologie
#
# **Cluster 188 (Label 56):**
#   *   Titles: analanjirofoantsinanana responsablede anj, qhse habitants alentours sabotsy namehana, bureau detude echantillonage habitants alentours sabotsy namehana, methode industriel habitants alentours sabotsy namehana, merchandiser habitants alentours sabotsy namehana
#
# **Cluster 189 (Label 73):**
#   *   Titles: directeur dhotel, maitre dhotel, directeur dhotel dirhotel, dhotel, matre dhotel
#
# **Cluster 190 (Label 43):**
#   *   Titles: chauffeur tourisme, consultant organisation restaurant consu org rest, hotel restaurant luxe site agro touristique, comptable detablissement hotelier, tourisme hotellerie
#   *   ... and 5 more.
#
# **Cluster 191 (Label 88):**
#   *   Titles: lead, sustainability lead, cat lead, lead developpeurnet seniors, lead tech react
#   *   ... and 5 more.
#
# **Cluster 192 (Label 77):**
#   *   Titles: serveur, barman barmaid, patronnier, barman b, barman
#   *   ... and 7 more.
#
# **Cluster 193 (Label 35):**
#   *   Titles: projet digital dequipe operation shipping, consignation commetant maritime, consignation maritime nosy, shipping, consignation maritime polyvalent nosy be
#   *   ... and 1 more.
#
# **Cluster 194 (Label 81):**
#   *   Titles: monteur youtube, montage video tiktok, createurcreatrice contenus videos youtube, monteur video graphiste mvg, monteur video
#   *   ... and 12 more.
#
# **Cluster 195 (Label 99):**
#   *   Titles: net, ingenieur docker net, nettoyeur, nettoyage
#
# **Cluster 196 (Label 165):**
#   *   Titles: animations, animateur animatrice, animateur commercial, graphic, animateur etou animatrice commaute
#   *   ... and 2 more.
#
# **Cluster 197 (Label 22):**
#   *   Titles: niveau, ist, call nuit, referent nuit, haut niveau
#
# **Cluster 198 (Label 282):**
#   *   Titles: bdm
#
# **Cluster 199 (Label 151):**
#   *   Titles: conseiller principal deducation
#
# **Cluster 200 (Label 251):**
#   *   Titles: creation, fabrication
#
# **Cluster 201 (Label 223):**
#   *   Titles: driver mentor, driver, personal driver
#
# **Cluster 202 (Label 257):**
#   *   Titles: amoroni mania ihorombe
#
# **Cluster 203 (Label 239):**
#   *   Titles: expert sig energies renouvelables
#
# **Cluster 204 (Label 62):**
#   *   Titles: property, setter
#
# **Cluster 205 (Label 108):**
#   *   Titles: ads, expert ads, expert publicites facebook google ads, social media maketing, facebook
#   *   ... and 1 more.
#
# **Cluster 206 (Label 191):**
#   *   Titles: gestion connaissances communication changement climatique migration interne, referent comptable migration, integrateur migration contenu
#
# **Cluster 207 (Label 198):**
#   *   Titles: dinternat, dinstallation confirme, dinstallation tech
#
# **Cluster 208 (Label 258):**
#   *   Titles: ingenieur daffaires preembauche remere formation metier multicloud infrastructure it embauche cdi, bid preembauche remere formation metier multicloud infrastructure it embauche cdi
#
# **Cluster 209 (Label 152):**
#   *   Titles: adjoint projet digital dagence sambava aca sambv, projet developpement durable sambava
#
# **Cluster 210 (Label 111):**
#   *   Titles: chr, ch metatrader
#
# **Cluster 211 (Label 102):**
#   *   Titles: trafic emailing, email designer expert figma, prospection email, traffic emailing bilingue franais italien, traffic emailing
#
# **Cluster 212 (Label 6):**
#   *   Titles: consultant expert zabbix glpi supervision integration itsm, cybersecurity architecture intern
#
# **Cluster 213 (Label 127):**
#   *   Titles: office, receptionist, operateur back office jior, back office, office facility
#   *   ... and 5 more.
#
# **Cluster 214 (Label 238):**
#   *   Titles: operationnel pedagogique, conseiller pedagogique, pedagogique
#
# **Cluster 215 (Label 27):**
#   *   Titles: jardinier pepinieriste, piste, garde piscine maurice, gardien jardinier, jardinier
#   *   ... and 1 more.
#
# **Cluster 216 (Label 221):**
#   *   Titles: it helpdesk analyst, helpdesk
#
# **Cluster 217 (Label 219):**
#   *   Titles: filemaker
#
# **Cluster 218 (Label 195):**
#   *   Titles: programmeur ity webgl, programmeur plc, programmeur javascript, programmeur php
#
# **Cluster 219 (Label 237):**
#   *   Titles: crochetteuse, projet digital datelier crochetraphia
#
# **Cluster 220 (Label 273):**
#   *   Titles: developpeurse mobile ios android flutter, developpeureuse mobile flutter, front end flutter confirme, flutter flow, developpeureuse flutter freelance
#
# **Cluster 221 (Label 279):**
#   *   Titles: stock preparation vehicules neufs, vehicules, vehicules neufs occasion
#
# **Cluster 222 (Label 270):**
#   *   Titles: salle, salle rps, matre dhotel salle, maitre salle, commis salle
#   *   ... and 1 more.
#
# **Cluster 223 (Label 13):**
#   *   Titles: conseillerere clientele propsecteur specialisee complements nutritionnels, nutrition sante, monitoring and evaluation coordinator transforming lives through nutrition flexible any cotry where helen keller has presence will be considered
#
# **Cluster 224 (Label 90):**
#   *   Titles: performance, controle performance, reporting performance operationnelle
#
# **Cluster 225 (Label 0):**
#   *   Titles: dop immobilier, equipements engins, business immobilier, dequipe, equipier
#   *   ... and 2 more.
#
# **Cluster 226 (Label 179):**
#   *   Titles: metteur point
#
# **Cluster 227 (Label 277):**
#   *   Titles: coach conduite, agents conduite ambatondrazaka
#
# **Cluster 228 (Label 212):**
#   *   Titles: process vanille sava
#
# **Cluster 229 (Label 285):**
#   *   Titles: menuisier
#
# **Cluster 230 (Label 155):**
#   *   Titles: recrutement agents appel sortant, call center expert appel sortant, appel sortant aps, appel sortant projet requalification fiche aps, deux production specialise appels sortants
#   *   ... and 2 more.
#
# **Cluster 231 (Label 265):**
#   *   Titles: administratif gestion inscriptions temps plein
#
# **Cluster 232 (Label 230):**
#   *   Titles: coordinnateurs pedagogique rugby for change, formateur rugby for change
#
# **Cluster 233 (Label 274):**
#   *   Titles: delevage black soldier fly, elevage black soldier fly
#
# **Cluster 234 (Label 256):**
#   *   Titles: facturier, facturation, facturation saisie comptable
#
# **Cluster 235 (Label 105):**
#   *   Titles: dop usine, hrbp, hrbp confirme
#
# **Cluster 236 (Label 224):**
#   *   Titles: exclusivement profil medicalsante data labeler annotation dimages ultrasons
#
# **Cluster 237 (Label 159):**
#   *   Titles: administratif import export, gestionnaire import export, logistique import export, importation
#
# **Cluster 238 (Label 203):**
#   *   Titles: interim suivi operationnel, suivi evaluation, maintenance suivi projets, suivi production
#
# **Cluster 239 (Label 194):**
#   *   Titles: detacheur, pieces detachees equipements engins poids lourd, pieces detachees
#
# **Cluster 240 (Label 84):**
#   *   Titles: annotateurs images videos nuages points textes, annotateur mathematiques amia, annotateurs audio
#
# **Cluster 241 (Label 253):**
#   *   Titles: rapprochement bancaire
#
# **Cluster 242 (Label 63):**
#   *   Titles: head of scm, fidelisation crm, crc
#
# **Cluster 243 (Label 150):**
#   *   Titles: trois, deux stagiaires qhse
#
# **Cluster 244 (Label 41):**
#   *   Titles: line, branch
#
# **Cluster 245 (Label 147):**
#   *   Titles: enseignant binome referent accompagnement pedagogique distance
#
# **Cluster 246 (Label 201):**
#   *   Titles: interimaires commication interne, comptable interim, interimaire tax accoting controller
#
# **Cluster 247 (Label 95):**
#   *   Titles: installation transmission tele prospecteurvision radio, apprenti ingenieur transmission fofh sdh, ingenieur radio design suivi projet interim
#
# **Cluster 248 (Label 235):**
#   *   Titles: commerial nosy be
#
# **Cluster 249 (Label 220):**
#   *   Titles: stagiaireapprenti media, medias modeles, media buyer
#
# **Cluster 250 (Label 180):**
#   *   Titles: refrigeration, specialise refrigeration climatisation
#
# **Cluster 251 (Label 280):**
#   *   Titles: geologue, psychologue clinicien
#
# **Cluster 252 (Label 89):**
#   *   Titles: responsables site hybride, site hybride manambaro
#
# **Cluster 253 (Label 157):**
#   *   Titles: governance risk compliance and culture intern
#
# **Cluster 254 (Label 225):**
#   *   Titles: head of transformation, transformation innovation
#
# **Cluster 255 (Label 54):**
#   *   Titles: tournant, windev
#
# **Cluster 256 (Label 260):**
#   *   Titles: quality insurance
#
# **Cluster 257 (Label 190):**
#   *   Titles: planification maintenance, planning, planification projet
#
# **Cluster 258 (Label 17):**
#   *   Titles: partenariats secteur formation digital, formation mldevsecops full remote
#
# **Cluster 259 (Label 255):**
#   *   Titles: linux embarque
#
# **Cluster 260 (Label 227):**
#   *   Titles: ingenieur detudes froid ventilation climatisation
#
# **Cluster 261 (Label 233):**
#   *   Titles: copper buyer
#
# **Cluster 262 (Label 241):**
#   *   Titles: controleur permanent flux, flux
#
# **Cluster 263 (Label 222):**
#   *   Titles: dispatcher medical, dispatcher logistique
#
# **Cluster 264 (Label 269):**
#   *   Titles: rehabilitation
#
# **Cluster 265 (Label 267):**
#   *   Titles: dynamics
#
# **Cluster 266 (Label 131):**
#   *   Titles: grands comptes, gens maison
#
# **Cluster 267 (Label 228):**
#   *   Titles: fdraising, fdraising officer
#
# **Cluster 268 (Label 119):**
#   *   Titles: site chariots elevateurs, conducteur chariot elevateur gerbeur, cariste conducteur chariot elevateur
#
# **Cluster 269 (Label 136):**
#   *   Titles: specialistes wash sbc, wash nutrition
#
# **Cluster 270 (Label 132):**
#   *   Titles: educateureducatrice specialisee jee, intelligence artificielle, journaliste experimente specialise intelligence artificielle, educateureducatrice specialisee petite enfance
#
# **Cluster 271 (Label 249):**
#   *   Titles: ruby
#
# **Cluster 272 (Label 106):**
#   *   Titles: installations, huit installateurs photovoltaques, mecanicien installateur
#
# **Cluster 273 (Label 217):**
#   *   Titles: professer dart primaire college
#
# **Cluster 274 (Label 199):**
#   *   Titles: temps reel
#
# **Cluster 275 (Label 287):**
#   *   Titles: avocat, avocat droit immobilier
#
# **Cluster 276 (Label 275):**
#   *   Titles: reseaux physiques rrp
#
# **Cluster 277 (Label 215):**
#   *   Titles: betsiboka base maevana
#
# **Cluster 278 (Label 174):**
#   *   Titles: etudes note calcul, ingenieur calcul base
#
# **Cluster 279 (Label 53):**
#   *   Titles: interprete chinois, enseignant mandarin chinois, traducteur chinois, maons
#
# **Cluster 280 (Label 268):**
#   *   Titles: si, si metier finance
#
# **Cluster 281 (Label 231):**
#   *   Titles: journaliste, journaliste polyvalent jnr p
#
# **Cluster 282 (Label 207):**
#   *   Titles: closer
#
# **Cluster 283 (Label 142):**
#   *   Titles: marches publics
#
# **Cluster 284 (Label 240):**
#   *   Titles: perspectiviste
#
# **Cluster 285 (Label 36):**
#   *   Titles: operateur extrusion, operateur machine decoupe laser
#
# **Cluster 286 (Label 209):**
#   *   Titles: technical sampling operator
#
# **Cluster 287 (Label 266):**
#   *   Titles: contenusemailing rce
#
# Cluster results saved to 'job_title_clusters.csv'
# 5935 lines retrieved from the database
# Total jobs: 5935
# Categorization rate: 82.1%
#
# Top categories:
# category
# Sales & Teleprospecting           1566
# Uncategorized / Other             1062
# Finance & Accounting               681
# Logistics & Supply Chain           385
# IT Development                     332
# Technical Trades & Engineering     279
# HR & Recruitment                   164
# Hospitality & Food Service         141
# Design & Digital Content           138
# Supervision & Management           133
# Name: count, dtype: int64
# Customer Service & Call Center : (45 titles):
#                                    title_clean      matched_keyword
# 0                            conseiller client    conseiller client
# 8              conseillers clients anglophones  conseillers clients
# 37                                        call                 call
# 73   conseiller client francophone experimente    conseiller client
# 107              conseiller client francophone    conseiller client
# Finance & Accounting : (211 titles):
#                     title_clean matched_keyword
# 1   administration comptabilite    comptabilite
# 51         comptable tresorerie       comptable
# 53             expert comptable       comptable
# 83                    comptable       comptable
# 92          comptable principal       comptable
# Specialized/Niche Roles : (13 titles):
#                       title_clean     matched_keyword
# 2              procurment officer  procurment officer
# 771         investment ref imedbm      investment ref
# 1842                  compositeur         compositeur
# 2220  valideur jour nuit valideur            valideur
# 2875                 copper buyer        copper buyer
# Logistics & Supply Chain : (185 titles):
#              title_clean matched_keyword
# 3          coursier moto        coursier
# 10           acheteur hf        acheteur
# 17                stocks          stocks
# 34    planificateur jior   planificateur
# 56  projet digital depot           depot
# Uncategorized / Other : (629 titles):
#                   title_clean matched_keyword
# 4      premiere seconde ligne            None
# 6                exploitation            None
# 12                 test tiana            None
# 13                     travel            None
# 15  sourcing qualification cv            None
# DevOps & Infrastructure : (39 titles):
#                         title_clean    matched_keyword
# 5                            reseau             reseau
# 116                      it analyst         it analyst
# 280  administrateur systemes reseau             reseau
# 306                      reseaux it         reseaux it
# 483  securite systemes dinformation  securite systemes
# Sales & Teleprospecting : (127 titles):
#                                      title_clean   matched_keyword
# 7                              charge commercial        commercial
# 18                                    commercial        commercial
# 30  repartition routiere tele propsecteurtravail       prospecteur
# 33                            delegue commercial        commercial
# 49                              tele prospecteur  tele prospecteur
# Retail & Merchandising : (24 titles):
#                     title_clean      matched_keyword
# 11   egerie ambassadrice marque  egerie ambassadrice
# 200                merchandiser         merchandiser
# 262                 cosmetiques          cosmetiques
# 537                    caissier             caissier
# 544       caissiere snack pizza            caissiere
# Testing & QA : (34 titles):
#                                title_clean matched_keyword
# 14                                    qaqc            qaqc
# 127             controleur qualite ctq tnn         qualite
# 186        coach qualite departement appel         qualite
# 188                       controle qualite         qualite
# 384  qualite environnement suivievaluation         qualite
# Administration & Secretarial : (40 titles):
#                              title_clean     matched_keyword
# 16                               juriste             juriste
# 413          consultant juridique fiscal           juridique
# 420                            juridique           juridique
# 461       corporate dossiers dassurances  corporate dossiers
# 516  back office geolocalisation interim         back office
# Technical Trades & Engineering : (148 titles):
#                         title_clean matched_keyword
# 21   dessinateur metreur poste base     dessinateur
# 35                          solaire         solaire
# 71         electricite electronique     electricite
# 72                    bureau detude   bureau detude
# 78  economiste construction general    construction
# HR & Recruitment : (65 titles):
#                          title_clean          matched_keyword
# 22   auditeurs jiorsseniors recaudit              recrutement
# 32          work force management rh                       rh
# 125                               rh                       rh
# 167                 developpement rh                       rh
# 172          standardistes bilingues  standardistes bilingues
# Design & Digital Content : (68 titles):
#               title_clean    matched_keyword
# 25       commity confirme  community manager
# 38                content            content
# 164  designer experimente           designer
# 177      graphic designer           designer
# 206       commity ava dia  community manager
# IT Development : (191 titles):
#                                                                                               title_clean  \
# 27  ingenieurs developpement java confirme modernisation dapplication perspectives devolution ref devjava
# 76                                                                                     fullstack confirme
# 81                                                                                             app mobile
# 89                                                                                       ingenieur python
# 94                                                                                              lead java
#
#    matched_keyword
# 27            java
# 76       fullstack
# 81      app mobile
# 89          python
# 94            java
# Audit & Compliance : (34 titles):
#                          title_clean matched_keyword
# 28                              qhse            qhse
# 36   auditeur agriculture biologique        auditeur
# 54               compliance qhse rse            qhse
# 93         auditeur interne confirme        auditeur
# 162               conformite systeme      conformite
# Hospitality & Food Service : (83 titles):
#              title_clean     matched_keyword
# 48             cuisinier           cuisinier
# 84    cuisinierpatissier  cuisinierpatissier
# 160  boulanger patissier           patissier
# 211  reservation novotel         reservation
# 216            pizzaiolo           pizzaiolo
# Digital Marketing & E-Commerce : (44 titles):
#                        title_clean   matched_keyword
# 57   projet digital projet seo sea               seo
# 286      redaction seo copywriting               seo
# 292                  growth hacker     growth hacker
# 372               growth marketing  growth marketing
# 488                      affiliate         affiliate
# Maintenance : (50 titles):
#                      title_clean matched_keyword
# 59            aide maintenancier   maintenancier
# 258                  maintenance     maintenance
# 273    dexploitation maintenance     maintenance
# 416  maintenance project officer     maintenance
# 428          atelier particulier         atelier
# Education & Training : (79 titles):
#                                                  title_clean matched_keyword
# 62                                       professeur malagasy      professeur
# 201                                          coach formateur       formateur
# 231                             professeur danglais primaire      professeur
# 374                        instituteur etudiant inscrit cned     instituteur
# 407  formateur technologies avancees transformation digitale       formateur
# Supervision & Management : (91 titles):
#                                  title_clean matched_keyword
# 80                        directeur securite       directeur
# 257                     directeur operations       directeur
# 355                      directeur marketing       directeur
# 368                 directeur audit controle       directeur
# 373  directeur financier ressources humaines       directeur
# Data & AI : (38 titles):
#                           title_clean     matched_keyword
# 105  gestionnaire location commity ia                  ia
# 106           data analyst anglophone        data analyst
# 381                  devdata engineer    devdata engineer
# 699                extraction donnees  extraction donnees
# 711                      ingenieur bi        ingenieur bi
# ERP & Functional Consulting : (29 titles):
#                    title_clean   matched_keyword
# 111  projet digital projet erp               erp
# 152              consultant bi     consultant bi
# 195  consultant si ref datacsi     consultant si
# 267           business analyst  business analyst
# 308                       sage              sage
# Content Writing & Translation : (26 titles):
#                                                      title_clean  \
# 130                 interprete chinois malagasy malagasy chinois
# 417                                                redacteur bac
# 611                          redacteurtrice cours medecine sante
# 794                        transcripteurs audio franais canadien
# 1005  relecteurrelectrice document word franais controle qualite
#
#           matched_keyword
# 130            interprete
# 417             redacteur
# 611        redacteurtrice
# 794        transcripteurs
# 1005  relecteurrelectrice
# Security : (22 titles):
#                        title_clean matched_keyword
# 135                  inspecteur nr   inspecteur nr
# 161      securite routiere sinorsr        securite
# 382               securite parking        securite
# 831         securite sante travail        securite
# 1146  noou garde denfants domicile           garde
# Internships : (11 titles):
#                             title_clean matched_keyword
# 143   apprenti dao ref apprenti daoiste        apprenti
# 1231            apprenti data scientist        apprenti
# 1351                       apprenti frc        apprenti
# 2927              devops apprenti mlops        apprenti
# 3835                        apprenti rh        apprenti
# Health & Medical : (22 titles):
#                     title_clean  matched_keyword
# 150                  laborantin       laborantin
# 264                cosmetologue     cosmetologue
# 463  delegue medical dm toliara  delegue medical
# 808          pharmacien diplome       pharmacien
# 937        estheticienne suarez    estheticienne
# Production & Manufacturing : (52 titles):
#                                 title_clean         matched_keyword
# 223                                 paoiste                 paoiste
# 638                   production atsinanana              production
# 811                      production textile              production
# 815  adjoint responsbale production arp tnn              production
# 844                  operateurs polyvalents  operateurs polyvalents
# Telecommunications : (5 titles):
#                       title_clean              matched_keyword
# 316                       filaire                      filaire
# 469                 fibre optique                fibre optique
# 737                deploiement it               deploiement it
# 1073                operateur noc                operateur noc
# 5015  equipements geolocalisation  equipements geolocalisation
# Coaching & Sports : (10 titles):
#                            title_clean matched_keyword
# 578   coach sportif multidisciplinaire           coach
# 701     recherche coach sportif online           coach
# 1236                     driver mentor   driver mentor
# 1933                    coach conduite           coach
# 1970                    coach carriere           coach
# Agriculture & Environment : (15 titles):
#                       title_clean matched_keyword
# 848                     forestier       forestier
# 894          production paysannat       paysannat
# 956                           rse             rse
# 1185  sustainability officer base  sustainability
# 1486       jardinier pepinieriste       jardinier
# Domestic & Personal Services : (10 titles):
#                       title_clean         matched_keyword
# 1135   femmes menage polyvalentes           femmes menage
# 1148                 femme menage            femme menage
# 1385                     coiffeur                coiffeur
# 2797  homme dentretien polyvalent        homme dentretien
# 3385       educatrice prescolaire  educatrice prescolaire
# GIS & Geomatics : (7 titles):
#                             title_clean matched_keyword
# 1244  expert sig energies renouvelables             sig
# 1773                        topographes     topographes
# 1992                         topographe      topographe
# 2235                    geomaticien sig             sig
# 2439                           geologue        geologue
# 5935 lines retrieved from the database
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 2045 stored elements and shape (5935, 50)>
#   Coords	Values
#   (0, 10)	1.0
#   (7, 4)	1.0
#   (9, 4)	1.0
#   (29, 10)	1.0
#   (40, 29)	1.0
#   (41, 4)	1.0
#   (42, 29)	1.0
#   (43, 4)	1.0
#   (44, 29)	1.0
#   (45, 4)	1.0
#   (46, 4)	1.0
#   (49, 47)	1.0
#   (52, 4)	1.0
#   (55, 4)	1.0
#   (56, 29)	1.0
#   (57, 29)	0.4865787701334879
#   (57, 22)	0.6177544416899737
#   (57, 32)	0.6177544416899737
#   (58, 4)	1.0
#   (63, 44)	0.3309737955707876
#   (63, 34)	0.33362710221246006
#   (63, 39)	0.33362710221246006
#   (63, 48)	0.33362710221246006
#   (63, 45)	0.33362710221246006
#   (63, 35)	0.33362710221246006
#   :	:
#   (5840, 43)	1.0
#   (5846, 4)	1.0
#   (5852, 4)	1.0
#   (5859, 4)	1.0
#   (5863, 0)	1.0
#   (5865, 4)	1.0
#   (5866, 4)	1.0
#   (5867, 10)	1.0
#   (5870, 4)	1.0
#   (5872, 47)	1.0
#   (5875, 4)	1.0
#   (5880, 4)	1.0
#   (5884, 47)	1.0
#   (5885, 8)	1.0
#   (5893, 43)	1.0
#   (5896, 0)	1.0
#   (5899, 47)	1.0
#   (5902, 11)	1.0
#   (5908, 4)	1.0
#   (5911, 8)	1.0
#   (5915, 4)	1.0
#   (5920, 4)	1.0
#   (5926, 24)	1.0
#   (5929, 42)	1.0
#   (5933, 4)	1.0
# C:\Users\Sarah Ursula\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1365: ConvergenceWarning: Number of distinct clusters (43) found smaller than n_clusters (44). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Sarah Ursula\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1365: ConvergenceWarning: Number of distinct clusters (43) found smaller than n_clusters (45). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Sarah Ursula\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1365: ConvergenceWarning: Number of distinct clusters (43) found smaller than n_clusters (46). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Sarah Ursula\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1365: ConvergenceWarning: Number of distinct clusters (43) found smaller than n_clusters (47). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Sarah Ursula\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1365: ConvergenceWarning: Number of distinct clusters (43) found smaller than n_clusters (48). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Sarah Ursula\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1365: ConvergenceWarning: Number of distinct clusters (43) found smaller than n_clusters (49). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Sarah Ursula\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1365: ConvergenceWarning: Number of distinct clusters (43) found smaller than n_clusters (50). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Sarah Ursula\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1365: ConvergenceWarning: Number of distinct clusters (43) found smaller than n_clusters (51). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Sarah Ursula\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1365: ConvergenceWarning: Number of distinct clusters (43) found smaller than n_clusters (52). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Sarah Ursula\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1365: ConvergenceWarning: Number of distinct clusters (43) found smaller than n_clusters (53). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Sarah Ursula\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1365: ConvergenceWarning: Number of distinct clusters (43) found smaller than n_clusters (54). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Sarah Ursula\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1365: ConvergenceWarning: Number of distinct clusters (43) found smaller than n_clusters (55). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Sarah Ursula\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1365: ConvergenceWarning: Number of distinct clusters (43) found smaller than n_clusters (56). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Sarah Ursula\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1365: ConvergenceWarning: Number of distinct clusters (43) found smaller than n_clusters (57). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Sarah Ursula\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1365: ConvergenceWarning: Number of distinct clusters (43) found smaller than n_clusters (58). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Sarah Ursula\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1365: ConvergenceWarning: Number of distinct clusters (43) found smaller than n_clusters (59). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# best_k = 42, score = 0.9991575400168492
#     cluster  count
# 0         1   4349
# 1         0    592
# 2         2    134
# 3         3    128
# 4         5     61
# 5         4     51
# 6         6     49
# 7        10     45
# 8         7     43
# 9        11     39
# 10       12     34
# 11       14     33
# 12        8     30
# 13       13     26
# 14        9     25
# 15       17     20
# 16       22     17
# 17       18     16
# 18       29     16
# 19       19     15
# 20       26     14
# 21       23     14
# 22       15     14
# 23       21     14
# 24       16     14
# 25       25     14
# 26       27     14
# 27       20     14
# 28       31     13
# 29       28     13
# 30       33     13
# 31       24     13
# 32       30     13
# 33       32     13
# 34       34     11
# 35       35      3
# 36       38      2
# 37       36      2
# 38       39      1
# 39       41      1
# 40       37      1
# 41       40      1
