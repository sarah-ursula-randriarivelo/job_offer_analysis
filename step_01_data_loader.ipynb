# %% [markdown]
# ### Used libraries

# %%
import pandas as pd

# %% [markdown]
# ### Load data from csv datasets

# %%
df = pd.read_csv('datasets/job_offer.csv', delimiter= ';')

print(df.shape)
df.head(3)
# Out:
# (5935, 13)
#                                                  url  reference  \
# 0  https://www.portaljob-madagascar.com/emploi/vi...        NaN
# 1  https://www.portaljob-madagascar.com/emploi/vi...  ENG-C-CPP
# 2  https://www.portaljob-madagascar.com/emploi/vi...        NaN
#
#                       title  \
# 0             electronicien
# 1   c/c++ software engineer
# 2  manager developpement rh
#
#                                    detail_entrerpise  \
# 0  d'un petit commerce ne il y a plus de cent ans...
# 1  rejoignez astek madagascar, du groupe astek, p...
# 2                                   multisectorielle
#
#                                              mission  \
# 0  L'électronicien industriel est responsable de ...
# 1  Participez à des projets de transformation dig...
# 2  Rattaché à la Directrice des Ressources Humain...
#
#                                               profil  \
# 0  o solides connaissances en electronique indust...
# ...

# %% [markdown]
# ### Remove duplicates in urls and titles

# %%
df.drop_duplicates(subset=['url', 'title'])
print(df.shape)
df
# Out:
# (5935, 13)
#                                                     url    reference  \
# 0     https://www.portaljob-madagascar.com/emploi/vi...          NaN
# 1     https://www.portaljob-madagascar.com/emploi/vi...    ENG-C-CPP
# 2     https://www.portaljob-madagascar.com/emploi/vi...          NaN
# 3     https://www.portaljob-madagascar.com/emploi/vi...           VE
# 4     https://www.portaljob-madagascar.com/emploi/vi...          NaN
# ...                                                 ...          ...
# 5930  https://www.portaljob-madagascar.com/emploi/vi...          blp
# 5931  https://www.portaljob-madagascar.com/emploi/vi...      SinoRSR
# 5932  https://www.portaljob-madagascar.com/emploi/vi...  RESPCS-0125
# 5933  https://www.portaljob-madagascar.com/emploi/vi...          NaN
# 5934  https://www.portaljob-madagascar.com/emploi/vi...          NaN
#
#                                       title  \
# 0                             electronicien
# ...

# %% [markdown]
# ### Export data into csv

# %%
df.to_csv('datasets/job_offer_no_duplicate.csv')
