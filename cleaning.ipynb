# %%
# %run data_loader.ipynb import df_database_connection as df
from modules.stopword import stop_words
import re

def clean_text(text: str) -> str:
    """
    Clean text to prepare the matching with keyword_mapping.
        - Convert into lowercase
        - delete all punctuations (comma, dot, etc...)
        - Normalise spaces
        - Preserving commonly composed terms like "data scientist", "stagiaire informatique") 
   
    """
    if not isinstance(text, str):
        return ""

    # 1. Convert text to lowercase
    text= text.lower()
    
    # normalise spaces
    text = re.sub(r'\\n+', '\n', text)

    # 2. # Replace underscores, slashes with spaces (to separate words)
    text = re.sub(r"[-_/]", " ", text)

    # 3. # Delete all elements that is not a letter or a digit (with accents), a space, or a number
    text = re.sub(r"[^a-zàâäéèêëîïôöùûüç0-9\s]", " ", text)

    # - replace digits with an empty space
    text = re.sub(r"\d+", " ", text)

    # 4. Normalise multiple spaces
    text = re.sub(r"\s+", " ", text).strip()

    # - replacing unecessary terms like 'telma, galaxy', etc with an empty character
    text = re.sub(r"(telma|galaxy|diego|tamatave|axian|antananarivo|mahajanga|toamasina|andraharo|zone|futura|shore|andranomena|immeuble|mdg|batiment ariane|batiment|ariane|tana|antsirabe|fianarantsoa|kube|majunga|tolagnaro|er etage|mdg|mdg campus|campus)", '', text)

    # Removing french articles inside titles
    text = text.split()
    filtered_word = []
    for word in text:
        if word not in stop_words:
            word = filtered_word.append(word)
    text = ' '.join(filtered_word)

    return text

"""Apply the cleaning function to all object type columns except "profil_clean"""
for columns in df.select_dtypes('object').columns:
    if "profil_clean" not in columns: 
        df[columns] = df[columns].apply(clean_text)


df = df[['title_clean','mission_clean']]

df_clean_text = df
df_clean_text.head(3)
# Out:
# 5935 lines retrieved from the database
#                    title_clean  \
# 0            conseiller client
# 1  administration comptabilite
# 2           procurment officer
#
#                                                                                                                                                                                                                                                                                                                                                                                                                 mission_clean
# 0  etes passionnee relation client souhaitez rejoindre equipe dynamique recrutons conseiller client francophone appel entrant hf repondre besoins clients garantir satisfaction missions principales repondre appels entrants horaires alloues production identifier apporter solutions adaptees problematiques clients assurer respect planning couverture heures douverture service gerer appels efficacite delais impartis
# 1                                                                                                        recherchons administration comptabilite duree dun mois opportunite menant embauche apres evaluation performances profil recherche titulaire cours dobtention dun diplome administration comptabilite domaine connexe rigoureuxse organisee motivee integrer equipe dynamique maitrise outils bureautiques word excel
# 2                                                                                                                                                                                                                                            communiquer echanger base reguliere fournisseurs assurer disponibilite stock afin dobtenir taux couverture taux service rotation adequation politique societe celle fournisseurs
