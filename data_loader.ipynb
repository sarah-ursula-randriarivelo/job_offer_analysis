# %%
import pandas as pd
from sqlalchemy import create_engine

"""path to the localhost server"""
DATABASE_URI = 'postgresql://root:0000@192.168.1.120:5432/test'

"""SQL query to retrieve the data from the database"""
QUERY = "SELECT title_clean, mission_clean, profil_clean FROM test_schema.portaljob_test"

engine = create_engine(DATABASE_URI)

if __name__ == '__main__':

    try:
        df = pd.read_sql_query(QUERY, engine)

        print(f"{len(df)} lines retrieved from the database") 

    except Exception as e:
        raise Exception(f" >>> Error occurs during the SQL query {e}")

pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)
pd.set_option('display.max_row', None)

df_database_connection =  df

df_database_connection.head(3)
# Out:
# 5935 lines retrieved from the database
#                                title_clean  \
# 0                        conseiller client
# 1  stage en administration et comptabilite
# 2                       procurment officer
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   mission_clean  \
# ...
